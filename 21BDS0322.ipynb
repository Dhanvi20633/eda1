# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanvi20633/eda1/blob/main/21BDS0322.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'NAME: DHANVI V'
'REG NO:21BDS0322'
# Out:
# 'REG NO:21BDS0322'

# %%
'https://github.com/Dhanvi20633/eda1/blob/main/21BDS0322.ipynb'
# Out:
# 'https://github.com/Dhanvi20633/eda1/blob/main/21BDS0322.ipynb'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
url = "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/mroz.csv"
df = pd.read_csv(url)
df.head(10)
# Out:
#    rownames  inlf  hours  kidslt6  kidsge6  age  educ    wage  repwage  \
# 0         1     1   1610        1        0   32    12  3.3540     2.65
# 1         2     1   1656        0        2   30    12  1.3889     2.65
# 2         3     1   1980        1        3   35    12  4.5455     4.04
# 3         4     1    456        0        3   34    12  1.0965     3.25
# 4         5     1   1568        1        2   31    14  4.5918     3.60
# 5         6     1   2032        0        0   54    12  4.7421     4.70
# 6         7     1   1440        0        2   37    16  8.3333     5.95
# 7         8     1   1020        0        0   54    12  7.8431     9.98
# 8         9     1   1458        0        2   48    12  2.1262     0.00
# 9        10     1   1600        0        2   39    12  4.6875     4.15
#
#    hushrs  ...  faminc     mtr  motheduc  fatheduc  unem  city  exper  \
# 0    2708  ...   16310  0.7215        12         7   5.0     0     14
# ...

# %%
#data cleaning

# Shape of dataset
print("Shape:", df.shape)

# Check for nulls
print("\nMissing values:\n", df.isnull().sum())

# Data types
print("\nData types:\n", df.dtypes)
# Out:
# Shape: (753, 23)
#
# Missing values:
#  rownames      0
# inlf          0
# hours         0
# kidslt6       0
# kidsge6       0
# age           0
# educ          0
# wage        325
# repwage       0
# hushrs        0
# husage        0
# huseduc       0
# huswage       0
# faminc        0
# mtr           0
# motheduc      0
# fatheduc      0
# unem          0
# city          0
# exper         0
# nwifeinc      0
# lwage       325
# expersq       0
# dtype: int64
#
# Data types:
#  rownames      int64
# inlf          int64
# hours         int64
# kidslt6       int64
# kidsge6       int64
# age           int64
# educ          int64
# wage        float64
# repwage     float64
# hushrs        int64
# husage        int64
# huseduc       int64
# huswage     float64
# faminc        int64
# mtr         float64
# motheduc      int64
# fatheduc      int64
# unem        float64
# city          int64
# exper         int64
# nwifeinc    float64
# lwage       float64
# expersq       int64
# ...

# %%
#check data dimensions
df.shape  # (rows, columns)
# Out:
# (753, 23)

# %%
#check for missing values
dt = df.isnull()

# %%
dt
# Out:
#      rownames   inlf  hours  kidslt6  kidsge6    age   educ   wage  repwage  \
# 0       False  False  False    False    False  False  False  False    False
# 1       False  False  False    False    False  False  False  False    False
# 2       False  False  False    False    False  False  False  False    False
# 3       False  False  False    False    False  False  False  False    False
# 4       False  False  False    False    False  False  False  False    False
# ..        ...    ...    ...      ...      ...    ...    ...    ...      ...
# 748     False  False  False    False    False  False  False   True    False
# 749     False  False  False    False    False  False  False   True    False
# 750     False  False  False    False    False  False  False   True    False
# 751     False  False  False    False    False  False  False   True    False
# 752     False  False  False    False    False  False  False   True    False
#
# ...

# %%
#summary
df.describe()
# Out:
#          rownames        inlf        hours     kidslt6     kidsge6  \
# count  753.000000  753.000000   753.000000  753.000000  753.000000
# mean   377.000000    0.568393   740.576361    0.237716    1.353254
# std    217.516666    0.495630   871.314216    0.523959    1.319874
# min      1.000000    0.000000     0.000000    0.000000    0.000000
# 25%    189.000000    0.000000     0.000000    0.000000    0.000000
# 50%    377.000000    1.000000   288.000000    0.000000    1.000000
# 75%    565.000000    1.000000  1516.000000    0.000000    2.000000
# max    753.000000    1.000000  4950.000000    3.000000    8.000000
#
#               age        educ        wage     repwage       hushrs  ...  \
# count  753.000000  753.000000  428.000000  753.000000   753.000000  ...
# mean    42.537849   12.286853    4.177682    1.849734  2267.270916  ...
# std      8.072574    2.280246    3.310282    2.419887   595.566649  ...
# min     30.000000    5.000000    0.128200    0.000000   175.000000  ...
# ...

# %%
#deduplication
#identifying duplicated values
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 748    False
# 749    False
# 750    False
# 751    False
# 752    False
# Length: 753, dtype: bool

# %%
dt
# Out:
#      rownames   inlf  hours  kidslt6  kidsge6    age   educ   wage  repwage  \
# 0       False  False  False    False    False  False  False  False    False
# 1       False  False  False    False    False  False  False  False    False
# 2       False  False  False    False    False  False  False  False    False
# 3       False  False  False    False    False  False  False  False    False
# 4       False  False  False    False    False  False  False  False    False
# ..        ...    ...    ...      ...      ...    ...    ...    ...      ...
# 748     False  False  False    False    False  False  False   True    False
# 749     False  False  False    False    False  False  False   True    False
# 750     False  False  False    False    False  False  False   True    False
# 751     False  False  False    False    False  False  False   True    False
# 752     False  False  False    False    False  False  False   True    False
#
# ...

# %%
#handling missing values

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Load dataset
url = "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/mroz.csv"
df = pd.read_csv(url)

# Drop rows where 'wage' is missing
df = df.dropna(subset=['wage'])

# Select numeric features and drop target from feature set
X = df.drop(columns=['wage']).select_dtypes(include='number')

# Drop rows with any remaining NaNs in features
X = X.dropna()

# Align y with X index
y = df.loc[X.index, 'wage']

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Train model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict and evaluate
y_pred = model.predict(X_test)
print(" Model Evaluation")

print("R² Score:", r2_score(y_test, y_pred))
# Out:
#  Model Evaluation
# R² Score: 0.6929972390588475

# %%
# Encoding 'kidslt6', 'kidsge6', 'educ', etc. are already numerical
# Let's see if there are any categorical columns
print(df.select_dtypes(include='object').columns)

# If 'object' type columns exist, encode them
# df['column_name'] = df['column_name'].astype('category').cat.codes
# Out:
# Index([], dtype='object')

# %%
#performing analysis
#univariate
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
#check datatypes of each column
df.dtypes
# Out:
# rownames      int64
# inlf          int64
# hours         int64
# kidslt6       int64
# kidsge6       int64
# age           int64
# educ          int64
# wage        float64
# repwage     float64
# hushrs        int64
# husage        int64
# huseduc       int64
# huswage     float64
# faminc        int64
# mtr         float64
# motheduc      int64
# fatheduc      int64
# unem        float64
# city          int64
# exper         int64
# nwifeinc    float64
# lwage       float64
# expersq       int64
# dtype: object

# %%
print(df.describe())
pd.isna(df).any()
# Out:
#          rownames        inlf        hours     kidslt6     kidsge6  \
# count  753.000000  753.000000   753.000000  753.000000  753.000000
# mean   377.000000    0.568393   740.576361    0.237716    1.353254
# std    217.516666    0.495630   871.314216    0.523959    1.319874
# min      1.000000    0.000000     0.000000    0.000000    0.000000
# 25%    189.000000    0.000000     0.000000    0.000000    0.000000
# 50%    377.000000    1.000000   288.000000    0.000000    1.000000
# 75%    565.000000    1.000000  1516.000000    0.000000    2.000000
# max    753.000000    1.000000  4950.000000    3.000000    8.000000
#
#               age        educ        wage     repwage       hushrs  ...  \
# count  753.000000  753.000000  428.000000  753.000000   753.000000  ...
# mean    42.537849   12.286853    4.177682    1.849734  2267.270916  ...
# std      8.072574    2.280246    3.310282    2.419887   595.566649  ...
# min     30.000000    5.000000    0.128200    0.000000   175.000000  ...
# ...

# %%
#data analysis

# Summary statistics
print(df.describe())

# Grouping and aggregation
print(df.groupby('educ')['wage'].mean())
# Out:
#          rownames        inlf        hours     kidslt6     kidsge6  \
# count  753.000000  753.000000   753.000000  753.000000  753.000000
# mean   377.000000    0.568393   740.576361    0.237716    1.353254
# std    217.516666    0.495630   871.314216    0.523959    1.319874
# min      1.000000    0.000000     0.000000    0.000000    0.000000
# 25%    189.000000    0.000000     0.000000    0.000000    0.000000
# 50%    377.000000    1.000000   288.000000    0.000000    1.000000
# 75%    565.000000    1.000000  1516.000000    0.000000    2.000000
# max    753.000000    1.000000  4950.000000    3.000000    8.000000
#
#               age        educ        wage     repwage       hushrs  ...  \
# count  753.000000  753.000000  428.000000  753.000000   753.000000  ...
# mean    42.537849   12.286853    4.177682    1.849734  2267.270916  ...
# std      8.072574    2.280246    3.310282    2.419887   595.566649  ...
# min     30.000000    5.000000    0.128200    0.000000   175.000000  ...
# ...

# %%
bins = [30, 40, 50, 60, 70]
category = pd.cut(age, bins)
category
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-3155f85ec7c6> in <cell line: 0>()
#       1 bins = [30, 40, 50, 60, 70]
# ----> 2 category = pd.cut(age, bins)
#       3 category
#
# NameError: name 'age' is not defined

# %%
bins = [30, 40, 50, 60, 70]


de['age_group'] = pd.cut(de['age'], bins=bins, right=False)

# Display the result
print(de[['age', 'age_group']])
# Out:
#      age age_group
# 0     32  [30, 40)
# 1     30  [30, 40)
# 2     35  [30, 40)
# 3     34  [30, 40)
# 4     31  [30, 40)
# ..   ...       ...
# 423   36  [30, 40)
# 424   40  [40, 50)
# 425   43  [40, 50)
# 426   33  [30, 40)
# 427   30  [30, 40)
#
# [428 rows x 2 columns]
# <ipython-input-50-d70477c9f4f2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   de['age_group'] = pd.cut(de['age'], bins=bins, right=False)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt


# Step 1: Drop rows with missing target and missing features
df = df.dropna(subset=['wage'])  # target column
df = df.dropna()  # remove remaining rows with NaNs

# Step 2: Select only numeric columns (excluding target)
X = df.drop(columns=['wage']).select_dtypes(include='number')

# Step 3: Scale the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 4: Apply PCA
pca = PCA(n_components=2)  # Reduce to 2 dimensions
X_pca = pca.fit_transform(X_scaled)

# Step 5: Plot the result
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], alpha=0.7, edgecolors='k')
plt.title("PCA: 2D Projection of Features")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.grid(True)
plt.show()

# Optional: Check explained variance
print("Explained variance ratio:", pca.explained_variance_ratio_)
# Out:
# Explained variance ratio: [0.21065002 0.16859349]

# %%
# Out:
# age_group
# [30, 40)    180
# [40, 50)    170
# [50, 60)     77
# [60, 70)      1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))  # Set figure size
age_counts.plot(kind='bar', color='skyblue', edgecolor='black')

# Labels and title
plt.xlabel("Age Groups", fontsize=12)
plt.ylabel("Number of People", fontsize=12)
plt.title("Distribution of People in Age Groups", fontsize=14)
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal gridlines

# Show plot
plt.show()

# %%
#8. Distribution plot
sns.FacetGrid(de).map(sns.distplot,'age').add_legend()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
#wages
bins = [0,1,2,3,4,5,6]

#
de['wage_grp'] = pd.cut(de['wage'], bins=bins, right=False)

# Display the result
print(de[['wage', 'wage_grp']])
# Out:
#        wage wage_grp
# 0    3.3540   [3, 4)
# 1    1.3889   [1, 2)
# 2    4.5455   [4, 5)
# 3    1.0965   [1, 2)
# 4    4.5918   [4, 5)
# ..      ...      ...
# 423  2.3118   [2, 3)
# 424  5.3061   [5, 6)
# 425  5.8675   [5, 6)
# 426  3.4091   [3, 4)
# 427  4.0816   [4, 5)
#
# [428 rows x 2 columns]
# <ipython-input-49-7bfa41b85eb5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   de['wage_grp'] = pd.cut(de['wage'], bins=bins, right=False)

# %%
wage_counts = de['wage_grp'].value_counts().sort_index()

# %%
wage_counts
# Out:
# wage_grp
# [0, 1)    17
# [1, 2)    65
# [2, 3)    96
# [3, 4)    76
# [4, 5)    69
# [5, 6)    33
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))  # Set figure size
wage_counts.plot(kind='bar', color='lightcoral', edgecolor='black')

# Labels and title
plt.xlabel("Wage Ranges", fontsize=12)
plt.ylabel("Number of Employees", fontsize=12)
plt.title("Distribution of Employees by Wage Groups", fontsize=14)
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal gridlines

# Show plot
plt.show()

# %%
#8. Distribution plot
sns.FacetGrid(de).map(sns.distplot,'wage').add_legend()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
#bivariate analysis
#age and wage
#using scatterplot
plt.scatter(de["age"], de["wage"])
plt.title("Scatter Plot for age vs wage")
plt.xlabel("age")
plt.ylabel("wage")
# Out:
# Text(0, 0.5, 'wage')

# %%
#Relationshipt between two features (Positive Correlation)
np.corrcoef(de["age"], de["hours"])
# Out:
# array([[1.        , 0.05486465],
#        [0.05486465, 1.        ]])

# %%
#Relationshipt between two features (Negative Correlation)
np.corrcoef(de["age"], de["hours"])
# Out:
# array([[1.        , 0.05486465],
#        [0.05486465, 1.        ]])

# %%
#boxplot
sns.boxplot(x="age", y="hours", data=de)
# Out:
# <Axes: xlabel='age', ylabel='hours'>

# %%
#multivariate analysis
sns.pairplot(de,vars = ['age', 'wage','hours'], kind="reg")
plt.show()

# %%
# To find the correlation among the entire numerical records
# the columns using pearson method
correlation = de.corr(method='pearson', numeric_only=True)
correlation
# Out:
#           rownames  inlf     hours   kidslt6   kidsge6       age      educ  \
# rownames  1.000000   NaN -0.009628 -0.018163  0.032860 -0.067815  0.006735
# inlf           NaN   NaN       NaN       NaN       NaN       NaN       NaN
# hours    -0.009628   NaN  1.000000 -0.168191 -0.176130  0.054865 -0.064879
# kidslt6  -0.018163   NaN -0.168191  1.000000  0.090690 -0.338447  0.129340
# kidsge6   0.032860   NaN -0.176130  0.090690  1.000000 -0.397554 -0.092536
# age      -0.067815   NaN  0.054865 -0.338447 -0.397554  1.000000 -0.052171
# educ      0.006735   NaN -0.064879  0.129340 -0.092536 -0.052171  1.000000
# wage      0.073182   NaN -0.097628  0.031423 -0.079228  0.030394  0.341954
# repwage  -0.042499   NaN  0.268609 -0.029837 -0.133720  0.004025  0.243486
# hushrs    0.034241   NaN -0.016234 -0.018953  0.115269 -0.121513  0.095877
# husage   -0.030453   NaN  0.045849 -0.352955 -0.354692  0.894423 -0.069858
# ...

# %%
sns.heatmap(correlation,xticklabels=correlation.columns,
            yticklabels=correlation.columns)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# Load dataset
url = "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/mroz.csv"
df = pd.read_csv(url)

# Drop rows with missing target (wage)
df = df.dropna(subset=['wage'])

# Select features and target
X = df.drop(columns=['wage'])
y = df['wage']

# Keep only numeric features
X = X.select_dtypes(include='number')

# Drop rows where features have missing values
X = X.dropna()
y = y.loc[X.index]  # align target

# Impute missing values (optional if already dropped)
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Build model
model = LinearRegression()

# Train model
model.fit(X_train, y_train)

print("Model has been built and trained successfully!")
# Out:
# Model has been built and trained successfully!

# %%
# Histogram
sns.histplot(df['age'], kde=True)
plt.title("Distribution of Age")
plt.show()

# Boxplot
sns.boxplot(x=df['age'])
plt.title("Boxplot of Age")
plt.show()

# Barplot for categorical variable
sns.countplot(x='educ', data=df)
plt.title("Count of Education Levels")
plt.show()

# %%
#bivariate analysis
# Scatter plot: age vs wage
sns.scatterplot(x='age', y='wage', data=df)
plt.title("Age vs Wage")
plt.show()

# Boxplot: education vs wage
sns.boxplot(x='educ', y='wage', data=df)
plt.title("Wage by Education Level")
plt.show()

# Correlation heatmap
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
#Multivariate Analysis
# Pairplot for selected features
sns.pairplot(df[['age', 'educ', 'wage']])
plt.suptitle("Pairplot of Age, Education, and Wage", y=1.02)
plt.show()

# Grouped Boxplot: education + kidslt6 vs wage
sns.boxplot(x='educ', y='wage', hue='kidslt6', data=df)
plt.title("Wage by Education and Kids < 6")
plt.show()

# %%
from scipy.stats import norm
df = df.dropna(subset=['wage'])  # Drop NaNs from wage

# Extract 'wage' column
wage_data = df['wage'].values

# MLE using scipy's norm.fit (estimates μ and σ)
mu_mle, std_mle = norm.fit(wage_data)

print(" MLE Estimated Mean (μ):", mu_mle)
print(" MLE Estimated Std Dev (σ):", std_mle)

# Plot the estimated distribution
plt.figure(figsize=(8, 6))
sns.histplot(wage_data, bins=30, kde=False, stat='density', color='skyblue', label='Wage Data')

# Plot MLE normal curve
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu_mle, std_mle)
plt.plot(x, p, 'r', linewidth=2, label='MLE Normal Fit')

plt.title("MLE Fit to Wage Data")
plt.xlabel("Wage")
plt.ylabel("Density")
plt.legend()
plt.grid(True)
plt.show()
# Out:
#  MLE Estimated Mean (μ): 4.177681541157382
#  MLE Estimated Std Dev (σ): 3.3064129608760724
